# %% [markdown]
# <a href="https://colab.research.google.com/github/ayelabolafunmilola30-alt/gdp-dashboard/blob/main/Exercise_1_5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1.5.1
#
# 13 students have taken an exam. Their scores are:
# 10, 15, 10, 9, 18, 16, 14, 12, 16, 13, 15, 20, and 17.
#
# You are a teacher and need to help recording these grades.
#
# - Create a list of these scores and assign it to a variable named `marks`.
#
# - Arrange the elements of `marks` in descending order.

# %% [markdown]
# # Solution

# %%
import matplotlib.pyplot as plt

# Create a histogram of the scores
plt.hist(marks, bins=range(min(marks), max(marks) + 2), edgecolor='black')

# Add labels and title for clarity
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Distribution of Exam Scores')

# Display the plot
plt.show()

# %%
import statistics

# Calculate the mode of the scores
mode_score = statistics.mode(marks)

# Print the mode score
print(f"The mode score is: {mode_score}")
# Out:
# The mode score is: 16

# %%
import statistics

# Calculate the median score
median_score = statistics.median(marks)

# Print the median score
print(f"The median score is: {median_score}")
# Out:
# The median score is: 15

# %%
# Calculate the average score
average_score = sum(marks) / len(marks)

# Print the average score
print(f"The average score is: {average_score:.2f}")
# Out:
# The average score is: 14.23

# %%
# Create a list of scores and name it `marks`.
marks = [10, 15, 10, 9, 18, 16, 14, 12, 16, 13, 15, 20, 17]

# Arrange the elements of `marks` in descending order.
marks.sort(reverse=True)

# Make sure you print your resulting list
print(marks)
# Out:
# [20, 18, 17, 16, 16, 15, 15, 14, 13, 12, 10, 10, 9]
